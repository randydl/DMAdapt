# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
T = np.load('T.npy')
T
# Out:
# array([[0.88535488, 0.01663503, 0.00697982, 0.00168726, 0.00308639,
#         0.04301919, 0.02199928, 0.01734168, 0.00286392, 0.00103261],
#        [0.01667215, 0.86023557, 0.02612364, 0.01765372, 0.00913016,
#         0.00682351, 0.01301816, 0.02972118, 0.01053841, 0.01008347],
#        [0.01696971, 0.00266567, 0.89191425, 0.05604497, 0.00266029,
#         0.00151002, 0.01100782, 0.00895799, 0.00469567, 0.00357362],
#        [0.01488249, 0.01084086, 0.00533115, 0.79397494, 0.00425145,
#         0.12660396, 0.00232526, 0.01469986, 0.01545676, 0.01163327],
#        [0.02483158, 0.04643849, 0.03173427, 0.00957914, 0.68527788,
#         0.03029833, 0.07021446, 0.01733645, 0.0278117 , 0.05647773],
#        [0.08566571, 0.0285667 , 0.00981501, 0.04644366, 0.00480417,
#         0.72270608, 0.03649125, 0.02398655, 0.0334414 , 0.00807944],
#        [0.00942569, 0.00571613, 0.02040821, 0.00116812, 0.01251935,
#         0.00434241, 0.92170465, 0.00604542, 0.00300624, 0.01566387],
# ...

# %%
records_tsf = pd.read_csv('records_tsf.csv')
records_tsf
# Out:
#      epoch  train_loss  train_acc  val_loss  val_acc  test_acc
# 0        0    1.088656   0.721333  0.749409    0.908     0.622
# 1        1    0.909796   0.724444  0.628087    0.904     0.638
# 2        2    0.839244   0.725778  0.580707    0.898     0.654
# 3        3    0.765796   0.728889  0.542528    0.902     0.676
# 4        4    0.742063   0.724667  0.520225    0.906     0.664
# ..     ...         ...        ...       ...      ...       ...
# 195    195    0.287371   0.811333  0.236700    0.954     0.686
# 196    196    0.283470   0.812000  0.246208    0.954     0.674
# 197    197    0.284786   0.810222  0.266734    0.950     0.680
# 198    198    0.288096   0.813556  0.235158    0.948     0.690
# 199    199    0.291156   0.815556  0.239073    0.962     0.670
#
# [200 rows x 6 columns]

# %%
props = ['train_loss', 'val_loss']
for p in props:
    plt.plot(records_tsf[p])
plt.legend(props)

# %%
props = ['train_acc', 'val_acc', 'test_acc']
for p in props:
    plt.plot(records_tsf[p])
plt.legend(props)
